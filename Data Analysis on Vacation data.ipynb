# %% [markdown]
# # Data Analytics of Vacation Data
# ## Inport The Required Libraries

# %%
import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the Dataset

# %%
df_vacation_data = pd.read_excel('vacation data.xlsx')

# %% [markdown]
# ## Data Overview

# %%
df_vacation_data.head()
# Out:
#    Gender  Age  Education                  Occupation State  \
# 0  Female   25        6.0  Clerical or service worker   VIC
# 1  Female   31        8.0                professional    WA
# 2    Male   21        3.0                         NaN   NSW
# 3  Female   18        2.0                  unemployed   NSW
# 4    Male   61        3.0                     retired    WA
#
#   Relationship_Status  Obligation_Rating Obligation_Category       NEP  \
# 0              single           4.800000                  Q4  3.200000
# 1             married           3.300000                  Q1  3.400000
# 2              single           3.400000                  Q2  3.066667
# 3              single           2.633333                  Q1  3.400000
# 4             married           3.400000                  Q2  3.733333
#
#    Vacation_Behaviour  ... Life_style_of_the_local_people  \
# 0            2.066667  ...                             no
# ...

# %%
df_vacation_data.tail()
# Out:
#      Gender  Age  Education                Occupation State  \
# 995    Male   51        3.0  manager or administrator   VIC
# 996    Male   58        4.0      small business owner    WA
# 997    Male   41        8.0              professional   QLD
# 998  Female   42        3.0              professional   VIC
# 999  Female   32        6.0  manager or administrator    WA
#
#        Relationship_Status  Obligation_Rating Obligation_Category       NEP  \
# 995  separated or divorced           2.366667                  Q1  3.400000
# 996  living with a partner           4.400000                  Q4  3.866667
# 997                married           3.866667                  Q3  3.400000
# 998  living with a partner           4.000000                  Q3  3.133333
# 999  living with a partner           2.333333                  Q1  3.600000
#
#      Vacation_Behaviour  ... Life_style_of_the_local_people  \
# 995            2.565217  ...                            yes
# ...

# %%
# Show the shape of the data
df_vacation_data.shape
# Out:
# (1000, 32)

# %%
# Make a small program utilize for adding two numbers :
# define input :

x=int(input("Enter the value of x"))
y=int(input("Enter the value of y"))

def Add(a, b):
    c=a+b
    print("The Addition is : ",c)

Add(x, y)
# Out:
# Enter the value of x 4
# Enter the value of y 5
# The Addition is :  9

# %%
# Anuther way to print the value :

x=int(input("Enter the value of x"))
y=int(input("Enter the value of y"))

def Add(a, b):
    c=a+b
    return c

Add(x, y)
# Out:
# Enter the value of x 5
# Enter the value of y 5
# 10

# %%
# Anuther way to print the value :

def Add():
    x=int(input("Enter the value of x"))
    y=int(input("Enter the value of y"))
    c=x+y
    return c

Add()
# Out:
# Enter the value of x 6
# Enter the value of y 1
# 7

# %% [markdown]
# **Interpretaion**
#  - we have 1000 Observation[rows]
#  - we have 32 Attrbutes[colums]

# %%
df_vacation_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Gender                                1000 non-null   object
#  1   Age                                   1000 non-null   int64
#  2   Education                             992 non-null    float64
#  3   Occupation                            941 non-null    object
#  4   State                                 1000 non-null   object
#  5   Relationship_Status                   996 non-null    object
#  6   Obligation_Rating                     1000 non-null   float64
#  7   Obligation_Category                   1000 non-null   object
#  8   NEP                                   1000 non-null   float64
#  9   Vacation_Behaviour                    975 non-null    float64
#  10  Rest_and_relax                        1000 non-null   object
# ...

# %% [markdown]
#  ### Interpretaion
#  - we have total 7 numarical colums and 25 categorical colums.
#  - memory usage: 250.1+ KB that we mens we do not requeried extra resourses.
#  - after observing the output, we can say that missing recordes are there in the data.

# %%
# justify the basic statstics of the data
df_vacation_data.describe()
# Out:
#                Age   Education  Obligation_Rating          NEP  \
# count  1000.000000  992.000000        1000.000000  1000.000000
# mean     44.168000    4.813508           3.734767     3.648600
# std      14.539228    2.422252           0.635777     0.561135
# min      18.000000    1.000000           1.000000     1.733333
# 25%      32.000000    3.000000           3.366667     3.266667
# 50%      42.000000    6.000000           3.800000     3.666667
# 75%      57.000000    7.000000           4.200000     4.066667
# max     105.000000    8.000000           5.000000     5.000000
#
#        Vacation_Behaviour  Income_Doller_k  Expenditure_Doller_k
# count          975.000000       200.000000            200.000000
# mean             2.962800        60.560000             50.200000
# std              0.668347        26.264721             25.823522
# min              1.233333        15.000000              1.000000
# 25%              2.466667        41.500000             34.750000
# ...

# %%
# justify the basic statstics of the data
df_vacation_data.describe().T
# Out:
#                        count       mean        std        min        25%  \
# Age                   1000.0  44.168000  14.539228  18.000000  32.000000
# Education              992.0   4.813508   2.422252   1.000000   3.000000
# Obligation_Rating     1000.0   3.734767   0.635777   1.000000   3.366667
# NEP                   1000.0   3.648600   0.561135   1.733333   3.266667
# Vacation_Behaviour     975.0   2.962800   0.668347   1.233333   2.466667
# Income_Doller_k        200.0  60.560000  26.264721  15.000000  41.500000
# Expenditure_Doller_k   200.0  50.200000  25.823522   1.000000  34.750000
#
#                             50%        75%    max
# Age                   42.000000  57.000000  105.0
# Education              6.000000   7.000000    8.0
# Obligation_Rating      3.800000   4.200000    5.0
# NEP                    3.666667   4.066667    5.0
# Vacation_Behaviour     2.944444   3.428571    4.9
# Income_Doller_k       61.500000  78.000000  137.0
# ...

# %% [markdown]
# #### when data is normaly distrubited
#  - Outlyer +5% or -5%
#  - Outlyer = mean/data of 50%

# %% [markdown]
# #### We dont have any outlyers in this dataset

# %% [markdown]
# ## Data Preprocessing ##

# %%
# null value handaling
# shoe the count of null records in the data

df_vacation_data.isnull()
# Out:
#      Gender    Age  Education  Occupation  State  Relationship_Status  \
# 0     False  False      False       False  False                False
# 1     False  False      False       False  False                False
# 2     False  False      False        True  False                False
# 3     False  False      False       False  False                False
# 4     False  False      False       False  False                False
# ..      ...    ...        ...         ...    ...                  ...
# 995   False  False      False       False  False                False
# 996   False  False      False       False  False                False
# 997   False  False      False       False  False                False
# 998   False  False      False       False  False                False
# 999   False  False      False       False  False                False
#
#      Obligation_Rating  Obligation_Category    NEP  Vacation_Behaviour  ...  \
# ...

# %%
df_vacation_data.isnull().sum()
# Out:
# Gender                                    0
# Age                                       0
# Education                                 8
# Occupation                               59
# State                                     0
# Relationship_Status                       4
# Obligation_Rating                         0
# Obligation_Category                       0
# NEP                                       0
# Vacation_Behaviour                       25
# Rest_and_relax                            0
# Luxury_be spoilt                          0
# Do_sports                                 0
# excitement_a_challenge                    0
# Not_exceed_planned_budget                 0
# Realise_creativity                        0
# Fun_and_entertainment                     0
# Good_company                              0
# Health_and_beauty                         0
# Free_and_easy_going                       0
# Entertainment_facilities                  0
# ...

# %% [markdown]
# #### Interpretation
#  - we have 8 null result in Education
#  - we have 59 null result in Occupation
#  - we have 4 null result in Relationship_Status
#  - we have 25 null result in Vacation_Behaviour
#  - we have 800 null result in Income_Doller_k
#  - we have 800 null result in Expenditure_Doller_k

# %% [markdown]
# #### lows to treat the null in manufacturing
#  - If null record % is lessthan 15% --> remove the observation (rows)
#  - If null record % is b/w 20-70% --> input the missing records (fill the missing values)
#  - If null record % is graterthan 75% --> remove the atributes (colums)

# %% [markdown]
# #### Fing the % missing record

# %%
df_vacation_data.isnull().sum()/len(df_vacation_data)*100
# Out:
# Gender                                   0.0
# Age                                      0.0
# Education                                0.8
# Occupation                               5.9
# State                                    0.0
# Relationship_Status                      0.4
# Obligation_Rating                        0.0
# Obligation_Category                      0.0
# NEP                                      0.0
# Vacation_Behaviour                       2.5
# Rest_and_relax                           0.0
# Luxury_be spoilt                         0.0
# Do_sports                                0.0
# excitement_a_challenge                   0.0
# Not_exceed_planned_budget                0.0
# Realise_creativity                       0.0
# Fun_and_entertainment                    0.0
# Good_company                             0.0
# Health_and_beauty                        0.0
# Free_and_easy_going                      0.0
# Entertainment_facilities                 0.0
# ...

# %% [markdown]
# ##### 0 Represent = row
# ##### 1 Represent = Columns

# %%
# asper the law lets remove the attributes
# missing persent > 75%

# --> Most Ez one
df_vacation_data.drop('Income_Doller_k',axis=1,inplace=True)

# --> Most use one mathods in componey
df_vacation_data=df_vacation_data.drop('Expenditure_Doller_k',axis=1)

# %%
# check the authontication
df_vacation_data.columns
# Out:
# Index(['Gender', 'Age', 'Education', 'Occupation', 'State',
#        'Relationship_Status', 'Obligation_Rating', 'Obligation_Category',
#        'NEP', 'Vacation_Behaviour', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %%
# for more check
df_vacation_data.shape
# Out:
# (1000, 30)

# %%
df_vacation_data.isnull().sum() / len(df_vacation_data) * 100
# Out:
# Gender                                  0.0
# Age                                     0.0
# Education                               0.8
# Occupation                              5.9
# State                                   0.0
# Relationship_Status                     0.4
# Obligation_Rating                       0.0
# Obligation_Category                     0.0
# NEP                                     0.0
# Vacation_Behaviour                      2.5
# Rest_and_relax                          0.0
# Luxury_be spoilt                        0.0
# Do_sports                               0.0
# excitement_a_challenge                  0.0
# Not_exceed_planned_budget               0.0
# Realise_creativity                      0.0
# Fun_and_entertainment                   0.0
# Good_company                            0.0
# Health_and_beauty                       0.0
# Free_and_easy_going                     0.0
# Entertainment_facilities                0.0
# ...

# %%
# drop the null arecord frnm the datafream
df_vacation_data.dropna(inplace = True)

# %%
# Authentication check
df_vacation_data.isnull().sum()
# Out:
# Gender                                  0
# Age                                     0
# Education                               0
# Occupation                              0
# State                                   0
# Relationship_Status                     0
# Obligation_Rating                       0
# Obligation_Category                     0
# NEP                                     0
# Vacation_Behaviour                      0
# Rest_and_relax                          0
# Luxury_be spoilt                        0
# Do_sports                               0
# excitement_a_challenge                  0
# Not_exceed_planned_budget               0
# Realise_creativity                      0
# Fun_and_entertainment                   0
# Good_company                            0
# Health_and_beauty                       0
# Free_and_easy_going                     0
# Entertainment_facilities                0
# Not_care_about_prices                   0
# ...

# %%
# Authentication check
df_vacation_data.shape
# Out:
# (912, 30)

# %% [markdown]
# ### Data Preprocessing is done....

# %% [markdown]
# ## EDA = Exploratory Data Analysis ##
#
# It is a method utilized to convert data into the information.
#
# 1. `Univariate Analysis`: When we take single column for analysis, it is called univariate analysis.
#     - We have 2 types of datatypes for analysis.
#     - Numerical: When we have only one numerical column, we plot the `Histogram or KDE plot`.
#     - Categorical: When we have only one categorical column, we plot `Count Plot`.
#
# 2. `Bivariate Analysis`: When we take two columns for analysis, it is called bivariate analysis.
#    - When we have two numerical column, we plot the `scatter plot`.
#    - When we have one numerical and one categorical column, we plot `Bar plot`.
#
# 3. `Multivariate Analysis`: When we take more than two columns for analysis, it is called multivariate analysis.
#    - In this case, we are going to create `Pair plot with HUE Parameter`. (Not recommended)
#    - In multivariate analysis, we create `Cross tab or Pivot table`.

# %% [markdown]
# # Universal Analysis

# %%
# secrigate the data based on data type

df_num = df_vacation_data.select_dtypes(include='number') # numerical datafream

df_cat = df_vacation_data.select_dtypes(include='object') # Categorical datafream

# %%
# show the first five numerical data
df_num.head()
# Out:
#    Age  Education  Obligation_Rating       NEP  Vacation_Behaviour
# 0   25        6.0           4.800000  3.200000            2.066667
# 1   31        8.0           3.300000  3.400000            2.000000
# 3   18        2.0           2.633333  3.400000            2.166667
# 4   61        3.0           3.400000  3.733333            1.724138
# 5   63        7.0           4.400000  4.266667            3.300000

# %%
# show the first five Categorical data
df_cat.head()
# Out:
#    Gender                  Occupation State Relationship_Status  \
# 0  Female  Clerical or service worker   VIC              single
# 1  Female                professional    WA             married
# 3  Female                  unemployed   NSW              single
# 4    Male                     retired    WA             married
# 5  Female                     retired   QLD             married
#
#   Obligation_Category Rest_and_relax Luxury_be spoilt Do_sports  \
# 0                  Q4            yes               no        no
# 1                  Q1            yes              yes        no
# 3                  Q1            yes              yes        no
# 4                  Q2            yes               no        no
# 5                  Q4            yes               no        no
#
#   excitement_a_challenge Not_exceed_planned_budget  ...  \
# 0                     no                        no  ...
# 1                     no                        no  ...
# ...

# %% [markdown]
# ### Perfom the univariate analysis on numerical data

# %%
# show the numerical columns
df_num.columns
# Out:
# Index(['Age', 'Education', 'Obligation_Rating', 'NEP', 'Vacation_Behaviour'], dtype='object')

# %% [markdown]
# #### Age

# %%
# show the minimum
df_num.Age.min()
# Out:
# 18

# %%
# show the maximum
df_num.Age.max()
# Out:
# 105

# %%
# show the Avarage
df_num.Age.mean().round(2)
# Out:
# 44.22

# %%
# show the distribution of the single numreical columns
df_num.Age.plot(kind='kde',color='black') # kernal dencity plot
# Out:
# <Axes: ylabel='Density'>

# %%
# show the distribution of the single numreical columns
df_num.Age.plot(kind='kde',color='black',)
plt.grid()
plt.title('Age Distribution')
plt.show()

# %% [markdown]
#  ### Interpretaion
#
#  - Minimum Age of the person who is going for the vacation is 18
#  - maximum Age of the person who is going for the vacation is 105
#  - Average Age of the person who is going for the vacation is 44.2
#  - the data follows multimode distribution
#  - we have two groups in the data ranges are between 25 to 49 and 50 to 60

# %%
# show the columns presented numerical datafram
df_num.columns
# Out:
# Index(['Age', 'Education', 'Obligation_Rating', 'NEP', 'Vacation_Behaviour'], dtype='object')

# %% [markdown]
# #### Education

# %%
df_num.Education.min()
# Out:
# 1.0

# %%
df_num.Education.max()
# Out:
# 8.0

# %%
df_num.Education.mean().round(2)
# Out:
# 4.88

# %%
df_num.Education.plot(kind='kde',color='black')
plt.grid()
plt.title('Education Distribution')
plt.show()

# %% [markdown]
#  ### Interpretaion
#
#  - Minimum Education of the person who is going for the vacation is 1
#  - maximum Education of the person who is going for the vacation is 8
#  - Average Education of the person who is going for the vacation is 4.8
#  - the data follows multimode distribution
#  - we have two groups in the data ranges are between 1 to 4 and 6 to 7

# %%
df_num.columns
# Out:
# Index(['Age', 'Education', 'Obligation_Rating', 'NEP', 'Vacation_Behaviour'], dtype='object')

# %% [markdown]
# #### Obligation_Rating

# %%
df_num.Obligation_Rating.min()
# Out:
# 1.0

# %%
df_num.Obligation_Rating.max()
# Out:
# 5.0

# %%
df_num.Obligation_Rating.mean()
# Out:
# 3.7352704678190785

# %%
df_num.Obligation_Rating.plot(kind='kde',color='black')
plt.grid()
plt.title('Obligation Rating Distribution')
plt.show()

# %% [markdown]
#  ### Interpretaion
#
#  - Minimum Obligation_Rating of the person who is going for the vacation is 1
#  - maximum Obligation_Rating of the person who is going for the vacation is 5
#  - Average Obligation_Rating of the person who is going for the vacation is 3.7
#  - the data follows normaly distribution

# %%
df_num.columns
# Out:
# Index(['Age', 'Education', 'Obligation_Rating', 'NEP', 'Vacation_Behaviour'], dtype='object')

# %% [markdown]
# ### NEP

# %%
df_num.NEP.min()
# Out:
# 1.733333333

# %%
df_num.NEP.max()
# Out:
# 5.0

# %%
df_num.NEP.mean()
# Out:
# 3.6469298245690793

# %%
df_num.NEP.plot(kind='kde',color='black')
plt.grid()
plt.title('NEP Distribution')
plt.show()

# %% [markdown]
#  ### Interpretaion
#
#  - Minimum NEP of the person who is going for the vacation is 1.7
#  - maximum NEP of the person who is going for the vacation is 5
#  - Average NEP of the person who is going for the vacation is 3.6
#  - the data follows normaly distribution

# %%
df_num.columns
# Out:
# Index(['Age', 'Education', 'Obligation_Rating', 'NEP', 'Vacation_Behaviour'], dtype='object')

# %% [markdown]
# ### Vacation_Behaviour

# %%
df_num.Vacation_Behaviour.min()
# Out:
# 1.392857143

# %%
df_num.Vacation_Behaviour.max()
# Out:
# 4.766666667

# %%
df_num.Vacation_Behaviour.mean()
# Out:
# 2.9620121344824555

# %%
df_num.Vacation_Behaviour.plot(kind='kde',color='black')
plt.grid()
plt.title('Vacation Behaviour Distribution')
plt.show()

# %% [markdown]
#  ### Interpretaion
#
#  - Minimum NEP of the person who is going for the vacation is 1.3
#  - maximum NEP of the person who is going for the vacation is 4.7
#  - Average NEP of the person who is going for the vacation is 2.9
#  - the data follows normaly distribution

# %% [markdown]
# ### Perfom the univariate analysis on Catagrical data

# %%
# show the first five Categorical data
df_cat.head()
# Out:
#    Gender                  Occupation State Relationship_Status  \
# 0  Female  Clerical or service worker   VIC              single
# 1  Female                professional    WA             married
# 3  Female                  unemployed   NSW              single
# 4    Male                     retired    WA             married
# 5  Female                     retired   QLD             married
#
#   Obligation_Category Rest_and_relax Luxury_be spoilt Do_sports  \
# 0                  Q4            yes               no        no
# 1                  Q1            yes              yes        no
# 3                  Q1            yes              yes        no
# 4                  Q2            yes               no        no
# 5                  Q4            yes               no        no
#
#   excitement_a_challenge Not_exceed_planned_budget  ...  \
# 0                     no                        no  ...
# 1                     no                        no  ...
# ...

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Gender

# %%
# show the count
df_cat.Gender.value_counts()
# Out:
# Gender
# Male      482
# Female    430
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Gender.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Gender')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
#  ### Interpretaion
#  - we have 482 Males and 430 Female

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Occupation

# %%
# show the count
df_cat.Occupation.value_counts()
# Out:
# Occupation
# professional                  253
# manager or administrator      180
# Clerical or service worker     99
# retired                        87
# home-duties                    75
# sales                          61
# small business owner           56
# unemployed                     35
# tradesperson                   27
# transport worker               20
# labourer                       19
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Occupation.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Gender')
plt.show()

# %% [markdown]
# ### Interpretation
#  - We have the count of professional is 253
#  - We have the count of  manager or administrator is 180
#  - We have the count of Clerical or service worker is99
#  - We have the count of retired is 87`
#  - We have the count of home-duties is 75
#  - We have the count of sales is 61
#  - We have the count of small business owner is 56
#  - We have the count of unemployed is 35
#  - We have the count of tradesperson is 27
#  - We have the count of transport worker is 20
#  - We have the count of labourer is 19"

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### State

# %%
# show the count
df_cat.State.value_counts()
# Out:
# State
# NSW    298
# VIC    245
# QLD    186
# WA      81
# SA      63
# ACT     21
# Tas     12
# NT       6
# Name: count, dtype: int64

# %%
# show the plot
df_cat.State.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Gender')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Interpretation
# - We have the count of NSW 298
# - We have the count of VIC 245
# - We have the count of QLD 186
# - We have the count of WA 81
# - We have the count of SA 63
# - We have the count of ACT 21
# - We have the count of Tas 12
# - We have the count of NT 6

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Relationship_Status

# %%
# show the count
df_cat.Relationship_Status.value_counts()
# Out:
# Relationship_Status
# married                  481
# single                   191
# living with a partner    133
# separated or divorced     95
# widowed                   12
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Relationship_Status.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Gender')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Interpretation
#  - We have the count of married people is 481
#  - We have the count of single is 191We have the count of living with a partner is 133
#  - We have the count of separated or divorced is 95
#  - We have the count of widowed is 126

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Obligation_Category

# %%
# show the count
df_cat.Obligation_Category.value_counts()
# Out:
# Obligation_Category
# Q2    238
# Q3    231
# Q1    226
# Q4    217
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Obligation_Category.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Obligation_Category')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Interpretation
#  - We have the count of Q2 is 238
#  - We have the count of Q3 is 231
#  - We have the count of Q1 is 226
#  - We have the count of Q4 is 217

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Rest_and_relax

# %%
# show the count
df_cat.Rest_and_relax.value_counts()
# Out:
# Rest_and_relax
# yes    825
# no      87
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Rest_and_relax.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Rest_and_relax')
plt.xticks(rotation=0)
plt.show()

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Luxury_be spoilt

# %%
# show the count
df_cat['Luxury_be spoilt'].value_counts()
# Out:
# Luxury_be spoilt
# no     659
# yes    253
# Name: count, dtype: int64

# %%
# show the plot
df_cat['Luxury_be spoilt'].value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Luxury_be spoilt')
plt.xticks(rotation=0)
plt.show()

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Do_sports

# %%
# show the count
df_cat.Do_sports.value_counts()
# Out:
# Do_sports
# no     784
# yes    128
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Do_sports.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Do_sports')
plt.xticks(rotation=0)
plt.show()

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Excitement_a_challenge

# %%
# show the count
df_cat.excitement_a_challenge.value_counts()
# Out:
# excitement_a_challenge
# no     601
# yes    311
# Name: count, dtype: int64

# %%
# show the plot
df_cat.excitement_a_challenge.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of excitement_a_challenge')
plt.xticks(rotation=0)
plt.show()

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Not_exceed_planned_budget

# %%
# show the count
df_cat.Not_exceed_planned_budget.value_counts()
# Out:
# Not_exceed_planned_budget
# yes    470
# no     442
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Not_exceed_planned_budget.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Not_exceed_planned_budget')
plt.xticks(rotation=0)
plt.show()

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Realise_creativity

# %%
# show the count
df_cat.Realise_creativity.value_counts()
# Out:
# Realise_creativity
# no     840
# yes     72
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Realise_creativity.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Realise_creativity')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Fun_and_entertainment

# %%
# show the count
df_cat.Fun_and_entertainment.value_counts()
# Out:
# Fun_and_entertainment
# yes    490
# no     422
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Fun_and_entertainment.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Fun_and_entertainment')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Good_company

# %%
# show the count
df_cat.Good_company.value_counts()
# Out:
# Good_company
# no     483
# yes    429
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Good_company.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Good_company')
plt.xticks(rotation=0)
plt.show()

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Health_and_beauty

# %%
# show the count
df_cat.Health_and_beauty.value_counts()
# Out:
# Health_and_beauty
# no     795
# yes    117
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Health_and_beauty.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Health_and_beauty')
plt.xticks(rotation=0)
plt.show()

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Free_and_easy_going

# %%
# show the count
df_cat.Free_and_easy_going.value_counts()
# Out:
# Free_and_easy_going
# yes    488
# no     424
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Free_and_easy_going.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Free_and_easy_going')
plt.xticks(rotation=0)
plt.show()

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Entertainment_facilities

# %%
# show the count
df_cat.Entertainment_facilities.value_counts()
# Out:
# Entertainment_facilities
# no     737
# yes    175
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Entertainment_facilities.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Entertainment_facilities')
plt.xticks(rotation=0)
plt.show()

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Not_care_about_prices

# %%
# show the count
df_cat.Not_care_about_prices.value_counts()
# Out:
# Not_care_about_prices
# no     743
# yes    169
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Not_care_about_prices.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Not_care_about_prices')
plt.xticks(rotation=0)
plt.show()

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Life_style_of_the_local_people

# %%
# show the count
df_cat.Life_style_of_the_local_people.value_counts()
# Out:
# Life_style_of_the_local_people
# no     484
# yes    428
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Life_style_of_the_local_people.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Life_style_of_the_local_people')
plt.xticks(rotation=0)
plt.show()

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Intense_Experience_of_Nature

# %%
df_cat.Intense_Experience_of_Nature.value_counts()
# Out:
# Intense_Experience_of_Nature
# no     715
# yes    197
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Intense_Experience_of_Nature.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Intense_Experience_of_Nature')
plt.xticks(rotation=0)
plt.show()

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Cosiness_or_Familiar_Atmosphere

# %%
df_cat.Cosiness_or_Familiar_Atmosphere.value_counts()
# Out:
# Cosiness_or_Familiar_Atmosphere
# no     744
# yes    168
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Cosiness_or_Familiar_Atmosphere.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Cosiness_or_Familiar_Atmosphere')
plt.xticks(rotation=0)
plt.show()

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Maintain_Unspoilt_Surroundings

# %%
df_cat.Maintain_Unspoilt_Surroundings.value_counts()
# Out:
# Maintain_Unspoilt_Surroundings
# no     631
# yes    281
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Maintain_Unspoilt_Surroundings.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Maintain_Unspoilt_Surroundings')
plt.xticks(rotation=0)
plt.show()

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Everything_Organised

# %%
df_cat.Everything_Organised.value_counts()
# Out:
# Everything_Organised
# no     764
# yes    148
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Everything_Organised.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Everything_Organised')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
#  ### Interpretaion
#  - We have 148 Yes and 764 No in Everything_Organised

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Unspoilt_Nature_or_Natural_Landscape

# %%
df_cat.Unspoilt_Nature_or_Natural_Landscape.value_counts()
# Out:
# Unspoilt_Nature_or_Natural_Landscape
# no     669
# yes    243
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Unspoilt_Nature_or_Natural_Landscape.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Unspoilt_Nature_or_Natural_Landscape')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
#  ### Interpretaion
#  - We have 669 No and 243 Yes in Unspoilt_Nature_or_Natural_Landscape

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Cultural_Offers

# %%
df_cat.Cultural_Offers.value_counts()
# Out:
# Cultural_Offers
# no     655
# yes    257
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Cultural_Offers.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Cultural_Offers')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
#  ### Interpretaion
#  - We have 655 No and 257 Yes in Cultural_Offers

# %%
# show the catagrical columns
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %% [markdown]
# ### Change_of_Surroundings

# %%
df_cat.Change_of_Surroundings.value_counts()
# Out:
# Change_of_Surroundings
# yes    623
# no     289
# Name: count, dtype: int64

# %%
# show the plot
df_cat.Change_of_Surroundings.value_counts().plot(kind='bar',color='#80B3FF')
plt.grid()
plt.title('Count of Change_of_Surroundings')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
#  ### Interpretaion
#  - we have 623 Yes and 289 No in Change_of_Surroundings

# %% [markdown]
# ### Bivariate analysis

# %%
df_num.columns
# Out:
# Index(['Age', 'Education', 'Obligation_Rating', 'NEP', 'Vacation_Behaviour'], dtype='object')

# %%
df_vacation_data.head()
# Out:
#    Gender  Age  Education                  Occupation State  \
# 0  Female   25        6.0  Clerical or service worker   VIC
# 1  Female   31        8.0                professional    WA
# 3  Female   18        2.0                  unemployed   NSW
# 4    Male   61        3.0                     retired    WA
# 5  Female   63        7.0                     retired   QLD
#
#   Relationship_Status  Obligation_Rating Obligation_Category       NEP  \
# 0              single           4.800000                  Q4  3.200000
# 1             married           3.300000                  Q1  3.400000
# 3              single           2.633333                  Q1  3.400000
# 4             married           3.400000                  Q2  3.733333
# 5             married           4.400000                  Q4  4.266667
#
#    Vacation_Behaviour  ... Entertainment_facilities Not_care_about_prices  \
# 0            2.066667  ...                       no                    no
# ...

# %%
# for finding the perls we need to drwa a co-relation matrix
df_num.corr()
# Out:
#                          Age  Education  Obligation_Rating       NEP  \
# Age                 1.000000  -0.174054           0.125080  0.081405
# Education          -0.174054   1.000000          -0.066768 -0.034149
# Obligation_Rating   0.125080  -0.066768           1.000000  0.358657
# NEP                 0.081405  -0.034149           0.358657  1.000000
# Vacation_Behaviour  0.134629  -0.090441           0.519562  0.266741
#
#                     Vacation_Behaviour
# Age                           0.134629
# Education                    -0.090441
# Obligation_Rating             0.519562
# NEP                           0.266741
# Vacation_Behaviour            1.000000

# %% [markdown]
# ### Interpretation
#  - we dont have any co-related Numrical columns

# %%
# plot the scater plot between Obligation_Rating and Vacation_Behaviour
sns.scatterplot(x='Obligation_Rating',y='Vacation_Behaviour',data=df_num)
plt.grid()

# %% [markdown]
# ### Bivariate analysis on 1 numerica snd 1 catagrical columns

# %%
df_cat.columns
# Out:
# Index(['Gender', 'Occupation', 'State', 'Relationship_Status',
#        'Obligation_Category', 'Rest_and_relax', 'Luxury_be spoilt',
#        'Do_sports', 'excitement_a_challenge', 'Not_exceed_planned_budget',
#        'Realise_creativity', 'Fun_and_entertainment', 'Good_company',
#        'Health_and_beauty', 'Free_and_easy_going', 'Entertainment_facilities',
#        'Not_care_about_prices', 'Life_style_of_the_local_people',
#        'Intense_Experience_of_Nature', 'Cosiness_or_Familiar_Atmosphere',
#        'Maintain_Unspoilt_Surroundings', 'Everything_Organised',
#        'Unspoilt_Nature_or_Natural_Landscape', 'Cultural_Offers',
#        'Change_of_Surroundings'],
#       dtype='object')

# %%
# show the numerical columns
df_num.columns
# Out:
# Index(['Age', 'Education', 'Obligation_Rating', 'NEP', 'Vacation_Behaviour'], dtype='object')

# %% [raw]
# Gender
# Age	Education
# Occupation	State
# Relationship_Status
# Obligation_Rating
# Obligation_Category
# NEP	Vacation_Behaviour
# Rest_and_relax
# Luxury_be spoilt
# Do_sports
# excitement_a_challenge
# Not_exceed_planned_budget
# Realise_creativity
# Fun_and_entertainment
# Good_company
# Health_and_beauty
# Free_and_easy_going
# Entertainment_facilities
# Not_care_about_prices
# Life_style_of_the_local_people
# Intense_Experience_of_Nature
# Cosiness_or_Familiar_Atmosphere
# Maintain_Unspoilt_Surroundings
# Everything_Organised
# Unspoilt_Nature_or_Natural_Landscape
# Cultural_Offers	Change_of_Surroundings
# Income_Doller_k	Expenditure_Doller_k

# %% [raw]
# Gender,Age
# Occupation,Age
# State,Age
# Relationship_Status,Age
# Obligation_Category,Age
# NEP,Age
# Vacation_Behaviour,Age
# Rest_and_relax,Age
# Luxury_be spoilt,Age
# Do_sports,Age
# excitement_a_challenge,Age
# Not_exceed_planned_budget,Age
# Realise_creativity,Age
# Fun_and_entertainment,Age
# Good_company,Age
# Health_and_beauty,Age
# Free_and_easy_going,Age
# Entertainment_facilities,Age
# Not_care_about_prices,Age
# Life_style_of_the_local_people,Age
# Intense_Experience_of_Nature,Age
# Cosiness_or_Familiar_Atmosphere,Age
# Maintain_Unspoilt_Surroundings,Age
# Everything_Organised,Age
# Unspoilt_Nature_or_Natural_Landscape,Age
# Cultural_Offers	Change_of_Surroundings,Age

# %%
sns.barplot(x='Gender',y='Age',data=df_vacation_data,color='#80B3FF',estimator='mean')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.barplot(x='Gender',y='Age',data=df_vacation_data,color='#80B3FF',estimator='min')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %%
sns.barplot(x='Gender',y='Age',data=df_vacation_data,color='#80B3FF',estimator='max')
# Out:
# <Axes: xlabel='Gender', ylabel='Age'>

# %% [markdown]
# ### Interpratation
#  - The data is quite beleanced
#  - everage age of male and female is live between 40-50

# %% [markdown]
# ##  Occupation,Age

# %%
sns.barplot(x='Occupation',y='Age',data=df_vacation_data,color='#80B3FF',estimator='mean')
plt.grid()
plt.title('Occupation VS Age')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Interpretation
#  - The data is not quite balanced
#  -

# %% [markdown]
# ## State,Age

# %%
sns.barplot(x='State', y='Age', data=df_vacation_data, color='#80B3FF', estimator='mean')
plt.grid()
plt.title('State Vs Age')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is quite balanced

# %% [markdown]
# ## Relationship_Status,Age

# %%
sns.barplot(x='Relationship_Status', y='Age', data=df_vacation_data, color='#80B3FF', estimator='mean')
plt.grid()
plt.title('Relationship_Status Vs Age')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Interpretation**
#  - The data is very imbalanced
